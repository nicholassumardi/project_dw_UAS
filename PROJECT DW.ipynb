# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
filepath = 'D:\PROJECT SMT 6\PROGRESS DW UAS NICHOLAS SUMARDI_06.2018.1.06977\SumberDataGabunganCSV.csv'
data = pd.read_csv(filepath, sep=';')

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    wanita        group B          bachelor's degree   standard
# 1    wanita        group C          some college        standard
# 2    wanita        group B          master's degree     standard
# 3    pria          group A          associate's degree  free/reduced
# 4    pria          group C          some college        standard
# ..      ...            ...                         ...           ...
# 995  wanita        group E          master's degree     standard
# 996  pria          group C          high school         free/reduced
# 997  wanita        group C          high school         free/reduced
# 998  wanita        group D          some college        standard
# 999  wanita        group D          some college        free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                 tidak ada          72             72             74
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  wanita        group B          bachelor's degree   standard
# 1  wanita        group C          some college        standard
# 2  wanita        group B          master's degree     standard
# 3  pria          group A          associate's degree  free/reduced
# 4  pria          group C          some college        standard
#
#   test preparation course  math score  reading score  writing score
# 0               tidak ada          72             72             74
# 1               lengkap            69             90             88
# 2               tidak ada          90             95             93
# 3               tidak ada          47             57             44
# 4               tidak ada          76             78             75

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  wanita        group E          master's degree     standard
# 996  pria          group C          high school         free/reduced
# 997  wanita        group C          high school         free/reduced
# 998  wanita        group D          some college        standard
# 999  wanita        group D          some college        free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               lengkap            88             99             95
# 996               tidak ada          62             55             55
# 997               lengkap            59             71             65
# 998               lengkap            68             78             77
# 999               tidak ada          77             86             86

# %%
row, col = data.shape
print(" Jumlah Baris :",row,"Jumlah Kolom :", col)
# Out:
#  Jumlah Baris : 1000 Jumlah Kolom : 8

# %%
list(data.columns)
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score']

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# # RATA-RATA NILAI BERDASARKAN GENDER

# %%
print('Nilai rata-rata \n')
print(df.groupby(['gender'])['math score', 'reading score', 'writing score'].mean())
# Out:
# Nilai rata-rata
#
#         math score  reading score  writing score
# gender
# pria     68.728216      65.473029      63.311203
# wanita   63.633205      72.608108      72.467181
# <ipython-input-61-0df3a55d6a47>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   print(df.groupby(['gender'])['math score', 'reading score', 'writing score'].mean())

# %% [markdown]
# # RATA-RATA NILAI BERDASARKAN RAS

# %%
print('Nilai rata-rata \n')
print(df.groupby(['race/ethnicity'])['math score', 'reading score', 'writing score'].mean())
# Out:
# Nilai rata-rata
#
#                 math score  reading score  writing score
# race/ethnicity
# group A          61.629213      64.674157      62.674157
# group B          63.452632      67.352632      65.600000
# group C          64.463950      69.103448      67.827586
# group D          67.362595      70.030534      70.145038
# group E          73.821429      73.028571      71.407143
# <ipython-input-62-a23d1dea181d>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   print(df.groupby(['race/ethnicity'])['math score', 'reading score', 'writing score'].mean())

# %% [markdown]
# # RATA-RATA NILAI BERDASARKAN LEVEL PENDIDIKAN ORTU

# %%
print('Nilai Rata-rata \n')
print(df.groupby(['parental level of education'])['math score', 'reading score', 'writing score'].mean())
# Out:
# Nilai Rata-rata
#
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268
# <ipython-input-60-f42b65d798bf>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   print(df.groupby(['parental level of education'])['math score', 'reading score', 'writing score'].mean())

# %% [markdown]
# # RATA-RATA NILAI BERDASARKAN MAKAN SIANG

# %%
print('Nilai Rata-rata \n')
print(df.groupby(['lunch'])['math score', 'reading score', 'writing score'].mean())
# Out:
# Nilai Rata-rata
#
#               math score  reading score  writing score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256
# <ipython-input-63-9fad6fe882a4>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   print(df.groupby(['lunch'])['math score', 'reading score', 'writing score'].mean())

# %% [markdown]
# # RATA-RATA NILAI BERDASARKAN PERSIAPAN TES

# %%
print('Nilai Rata-rata \n')
print(df.groupby(['test preparation course'])['math score', 'reading score', 'writing score'].mean())
# Out:
# Nilai Rata-rata
#
#                          math score  reading score  writing score
# test preparation course
# lengkap                   69.695531      73.893855      74.418994
# tidak ada                 64.077882      66.534268      64.504673
# <ipython-input-65-655203add72a>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   print(df.groupby(['test preparation course'])['math score', 'reading score', 'writing score'].mean())

# %% [markdown]
# # TOTAL RATA-RATA NILAI BERDASARKAN GENDER

# %%
print('Nilai Gabungan \n')
df['nilai gabungan rata-rata'] = df.iloc[:, -4:-2].mean(axis=1)
print(df.groupby(['gender'])['nilai gabungan rata-rata'].mean())
# Out:
# Nilai Gabungan
#
# gender
# pria      64.392116
# wanita    72.537645
# Name: nilai gabungan rata-rata, dtype: float64

# %% [markdown]
# # TOTAL RATA-RATA NILAI BERDASARKAN RAS

# %%
print('Nilai Gabungan \n')
df['nilai gabungan rata-rata'] = df.iloc[:, -4:-2].mean(axis=1)
print(df.groupby(['race/ethnicity'])['nilai gabungan rata-rata'].mean())
# Out:
# Nilai Gabungan
#
# race/ethnicity
# group A    63.674157
# group B    66.476316
# group C    68.465517
# group D    70.087786
# group E    72.217857
# Name: nilai gabungan rata-rata, dtype: float64

# %% [markdown]
# # TOTAL RATA-RATA NILAI BERDASARKAN LEVEL PENDIDIKAN ORANG TUA

# %%
print('Nilai Gabungan \n')
df['nilai gabungan rata-rata'] = df.iloc[:, -4:-2].mean(axis=1)
print(df.groupby(['parental level of education'])['nilai gabungan rata-rata'].mean())
# Out:
# Nilai Gabungan
#
# parental level of education
# associate's degree    70.412162
# bachelor's degree     73.190678
# high school           63.576531
# master's degree       75.525424
# some college          69.150442
# some high school      65.913408
# Name: nilai gabungan rata-rata, dtype: float64

# %% [markdown]
# # TOTAL RATA-RATA NILAI BERDASARKAN MAKAN SIANG

# %%
print('Nilai Gabungan \n')
df['nilai gabungan rata-rata'] = df.iloc[:, -4:-2].mean(axis=1)
print(df.groupby(['lunch'])['nilai gabungan rata-rata'].mean())
# Out:
# Nilai Gabungan
#
# lunch
# free/reduced    63.838028
# standard        71.238760
# Name: nilai gabungan rata-rata, dtype: float64

# %% [markdown]
# # TOTAL RATA-RATA NILAI BERDASARKAN PERSIAPAN TEST

# %%
print('Nilai Gabungan \n')
df['nilai gabungan rata-rata'] = df.iloc[:, -4:-2].mean(axis=1)
print(df.groupby(['test preparation course'])['nilai gabungan rata-rata'].mean())
# Out:
# Nilai Gabungan
#
# test preparation course
# lengkap      74.156425
# tidak ada    65.519470
# Name: nilai gabungan rata-rata, dtype: float64

# %% [markdown]
# # Grafik Rata-Rata Nilai Berdasarkan Gender

# %%
plt.figure(figsize=(10,6))
plt.title("Rata-Rata Nilai Baca Berdasarkan Gender")
df_melted = df.melt(id_vars=['gender'], value_vars=['math score', 'writing score', 'reading score'], var_name='score name', value_name='nilai rata-rata')

sns.barplot(data=df_melted, x='gender', y='nilai rata-rata', hue='score name')
# Out:
# <AxesSubplot:title={'center':'Rata-Rata Nilai Baca Berdasarkan Gender'}, xlabel='gender', ylabel='nilai rata-rata'>

# %% [markdown]
# # Grafik Rata-Rata Nilai Berdasarkan Ras

# %%
plt.figure(figsize=(10,6))
plt.title("Rata-Rata Nilai Baca Berdasarkan Ras")
df_melted2 = df.melt(id_vars=['race/ethnicity'], value_vars=['math score', 'writing score', 'reading score'], var_name='score name', value_name='nilai rata-rata')

sns.barplot(data=df_melted2, x='race/ethnicity', y='nilai rata-rata', hue='score name')
# Out:
# <AxesSubplot:title={'center':'Rata-Rata Nilai Baca Berdasarkan Ras'}, xlabel='race/ethnicity', ylabel='nilai rata-rata'>

# %% [markdown]
# # Grafik Rata-Rata Nilai Berdasarkan Level Pendidikan Orang Tua

# %%
plt.figure(figsize=(10,6))
plt.title("Rata-Rata Nilai Baca Berdasarkan Level Pendidikan Orang Tua")
df_melted3 = df.melt(id_vars=['parental level of education'], value_vars=['math score', 'writing score', 'reading score'], var_name='score name', value_name='nilai rata-rata')

sns.barplot(data=df_melted3, x='parental level of education', y='nilai rata-rata', hue='score name')
# Out:
# <AxesSubplot:title={'center':'Rata-Rata Nilai Baca Berdasarkan Level Pendidikan Orang Tua'}, xlabel='parental level of education', ylabel='nilai rata-rata'>

# %% [markdown]
# # Grafik Rata-Rata Nilai Berdasarkan Makan Siang

# %%
plt.figure(figsize=(10,6))
plt.title("Rata-Rata Nilai Baca Berdasarkan Makan Siang")
df_melted4 = df.melt(id_vars=['lunch'], value_vars=['math score', 'writing score', 'reading score'], var_name='score name', value_name='nilai rata-rata')

sns.barplot(data=df_melted4, x='lunch', y='nilai rata-rata', hue='score name')
# Out:
# <AxesSubplot:title={'center':'Rata-Rata Nilai Baca Berdasarkan Makan Siang'}, xlabel='lunch', ylabel='nilai rata-rata'>

# %% [markdown]
# # Grafik Rata-Rata Nilai Berdasarkan Persiapan Tes

# %%
plt.figure(figsize=(10,6))
plt.title("Rata-Rata Nilai Baca Berdasarkan Gender")
df_melted5 = df.melt(id_vars=['test preparation course'], value_vars=['math score', 'writing score', 'reading score'], var_name='score name', value_name='nilai rata-rata')

sns.barplot(data=df_melted5, x='test preparation course', y='nilai rata-rata', hue='score name')
# Out:
# <AxesSubplot:title={'center':'Rata-Rata Nilai Baca Berdasarkan Gender'}, xlabel='test preparation course', ylabel='nilai rata-rata'>

# %% [markdown]
# # Hubungan antara nilai rata-rata antara ras dengan Gender

# %%
plt.figure(figsize=(10,6))
plt.title("Hubungan nilai rata-rata antara Ras dengan Gender")
sns.swarmplot(x=df['race/ethnicity'],
              y=df['nilai gabungan rata-rata'], hue=df['gender'])
# Out:
# <AxesSubplot:title={'center':'Hubungan nilai rata-rata antara Ras dengan Gender'}, xlabel='race/ethnicity', ylabel='nilai gabungan rata-rata'>

# %% [markdown]
# # Hubungan antara nilai rata-rata antara Tingkat Pendidikan Orangtua dengan Gender

# %%
plt.figure(figsize=(10,6))
plt.title("Hubungan nilai rata-rata antara Tingkat Pendidikan Ortu dengan Gender")
sns.swarmplot(x=df['parental level of education'],
              y=df['nilai gabungan rata-rata'], hue=df['gender'])
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, "bachelor's degree "),
#   Text(1, 0, 'some college      '),
#   Text(2, 0, "master's degree   "),
#   Text(3, 0, "associate's degree"),
#   Text(4, 0, 'high school       '),
#   Text(5, 0, 'some high school  ')])

# %% [markdown]
# # Hubungan nilai rata-rata antara Makan Siang dengan Gender

# %%
plt.figure(figsize=(10,6))
plt.title("Hubungan nilai rata-rata antara Makan Siang dengan Gender")
sns.swarmplot(x=df['lunch'],
              y=df['nilai gabungan rata-rata'], hue=df['gender'])
# Out:
# <AxesSubplot:title={'center':'Hubungan nilai rata-rata antara Makan Siang dengan Gender'}, xlabel='lunch', ylabel='nilai gabungan rata-rata'>

# %% [markdown]
# #  Hubungan nilai rata-rata antara Persiapan Test dengan Gender

# %%
plt.figure(figsize=(10,6))
plt.title("Hubungan nilai rata-rata antara Persiapan Test dengan Gender")
sns.swarmplot(x=df['test preparation course'],
              y=df['nilai gabungan rata-rata'], hue=df['gender'])
# Out:
# <AxesSubplot:title={'center':'Hubungan nilai rata-rata antara Persiapan Test dengan Gender'}, xlabel='test preparation course', ylabel='nilai gabungan rata-rata'>
